# %%
import pandas as pd
data = pd.read_csv('C:/Users/kaurb/Downloads/data (1).csv')

# %%
data.head()
# Out:
#   S. No.          State/ UT  Fine - Total Acc. - 2014  \
# 0      1     Andhra Pradesh                   14591.0
# 1      2  Arunachal Pradesh                      71.0
# 2      3              Assam                    3575.0
# 3      4              Bihar                    2343.0
# 4      5       Chhattisgarh                    5000.0
#
#    Fine - Persons Killed - 2014  Fine - Persons Injured - 2014  \
# 0                          4586                        17065.0
# 1                            30                          110.0
# 2                          1318                         3216.0
# 3                          1218                         1626.0
# 4                          1354                         4584.0
#
#    Mist/fog - Total Acc. - 2014  Mist/fog - Persons Killed - 2014  \
# 0                         724.0                               219
# 1                          14.0                                10
# 2                         494.0                               150
# 3                        1713.0                               881
# 4                         382.0                               149
#
#    Mist/fog - Persons Injured - 2014  Cloudy - Total Acc. - 2014  \
# 0                              925.0                       647.0
# 1                               26.0                        11.0
# 2                              368.0                       285.0
# 3                             1081.0                       438.0
# 4                              376.0                       863.0
#
#    Cloudy - Persons Killed - 2014  ...  Snowfall - Persons Injured - 2016  \
# 0                           188.0  ...                                  0
# 1                             8.0  ...                                  0
# 2                           100.0  ...                                  0
# 3                           203.0  ...                                  0
# 4                           216.0  ...                                  0
#
#    Hail/Sleet - Total Accidents - 2016  Hail/Sleet - Persons Killed - 2016  \
# 0                                   92                                  45
# 1                                   12                                   7
# 2                                   15                                   8
# 3                                    0                                   0
# 4                                    0                                   0
#
#    Hail/Sleet - Persons Injured - 2016  Dust Storm - Total Accidents - 2016  \
# 0                                  137                                   42
# 1                                   13                                    0
# 2                                    5                                   36
# 3                                    0                                  582
# 4                                    0                                  132
#
#    Dust Storm - Persons Killed - 2016  Dust Storm - Persons Injured - 2016  \
# 0                                  34                                   61
# 1                                   0                                    0
# 2                                  14                                   19
# 3                                 318                                  399
# 4                                  28                                  151
#
#    Others - Total Accidents - 2016  Others - Persons Killed - 2016  \
# 0                             2839                            1086
# 1                               44                              22
# 2                             2188                             763
# 3                             1820                            1175
# 4                             3972                            1262
#
#    Others - Persons Injured - 2016
# 0                             3408
# 1                               91
# 2                             1752
# 3                             1247
# 4                             3793
#
# [5 rows x 65 columns]

# %%
# Shape of the data
print("Shape of the data: {}".format(data.shape))
# Out:
# Shape of the data: (37, 65)

# %%
data.columns
# Out:
# Index(['S. No.', 'State/ UT', 'Fine - Total Acc. - 2014',
#        'Fine - Persons Killed - 2014', 'Fine - Persons Injured - 2014',
#        'Mist/fog - Total Acc. - 2014', 'Mist/fog - Persons Killed - 2014',
#        'Mist/fog - Persons Injured - 2014', 'Cloudy - Total Acc. - 2014',
#        'Cloudy - Persons Killed - 2014', 'Cloudy - Persons Injured - 2014',
#        'Light rain - Total Acc. - 2014', 'Light rain - Persons Killed - 2014',
#        'Light rain - Persons Injured - 2014', 'Heavy rain - Total Acc. - 2014',
#        'Heavy rain - Persons Killed - 2014',
#        'Heavy rain - Persons Injured - 2014',
#        'Flooding of slipways/rivulers - Total Acc. - 2014',
#        'Flooding of slipways/rivulers - Persons Killed - 2014',
#        'Flooding of slipways/rivulers - Persons Injured - 2014',
#        'Hail/sleet - Total Acc. - 2014', 'Hail/sleet - Persons Killed - 2014',
#        'Hail/sleet - Persons Injured - 2014', 'snow - Total Acc. - 2014',
#        'snow - Persons Killed - 2014', 'snow - Persons Injured - 2014',
#        'Strong wind - Total Acc. - 2014',
#        'Strong wind - Persons Killed - 2014',
#        'Strong wind - Persons Injured - 2014',
#        'Dust storm - Total Acc. - 2014', 'Dust storm - Persons Killed - 2014',
#        'Dust storm - Persons Injured - 2014', 'Very hot - Total Acc. - 2014',
#        'Very hot - Persons Killed - 2014', 'Very hot - Persons Injured - 2014',
#        'Very cold - Total Acc. - 2014', 'Very cold - Persons Killed - 2014',
#        'Very cold - Persons Injured - 2014',
#        'Other extraordinary weather condition - Total Acc. - 2014',
#        'Other extraordinary weather condition - Persons Killed - 2014',
#        'Other extraordinary weather condition - Persons Injured - 2014',
#        'Fine/Clear - Total Accidents - 2016',
#        'Fine/Clear - Persons Killed - 2016',
#        'Fine/Clear - Persons Injured - 2016',
#        'Mist/ Foggy - Total Accidents - 2016',
#        'Mist/ Foggy - Persons Killed - 2016',
#        'Mist/ Foggy - Persons Injured - 2016',
#        'Cloudy - Total Accidents - 2016', 'Cloudy - Persons Killed - 2016',
#        'Cloudy - Persons Injured - 2016', 'Rainy - Total Accidents - 2016',
#        'Rainy - Persons Killed - 2016', 'Rainy - Persons Injured - 2016',
#        'Snowfall - Total Accidents - 2016', 'Snowfall - Persons Killed - 2016',
#        'Snowfall - Persons Injured - 2016',
#        'Hail/Sleet - Total Accidents - 2016',
#        'Hail/Sleet - Persons Killed - 2016',
#        'Hail/Sleet - Persons Injured - 2016',
#        'Dust Storm - Total Accidents - 2016',
#        'Dust Storm - Persons Killed - 2016',
#        'Dust Storm - Persons Injured - 2016',
#        'Others - Total Accidents - 2016', 'Others - Persons Killed - 2016',
#        'Others - Persons Injured - 2016'],
#       dtype='object')

# %%
data.dtypes
# Out:
# S. No.                                  object
# State/ UT                               object
# Fine - Total Acc. - 2014               float64
# Fine - Persons Killed - 2014             int64
# Fine - Persons Injured - 2014          float64
#                                         ...
# Dust Storm - Persons Killed - 2016       int64
# Dust Storm - Persons Injured - 2016      int64
# Others - Total Accidents - 2016          int64
# Others - Persons Killed - 2016           int64
# Others - Persons Injured - 2016          int64
# Length: 65, dtype: object

# %%
print("Number of integer columns: {}".format(data.dtypes.tolist().count(data.dtypes[0])))
print("Number of object columns: {}".format(data.dtypes.tolist().count(data.dtypes[20])))

# Count of duplicate rows
duplicate = data[data.duplicated() == True]
print("Number of duplicate rows: {}".format(len(duplicate)))
# Out:
# Number of integer columns: 2
# Number of object columns: 35
# Number of duplicate rows: 0

# %%
# Count of missing values in each column - TO BE DONE IN R
data.isna().sum()
# Out:
# S. No.                                 0
# State/ UT                              0
# Fine - Total Acc. - 2014               1
# Fine - Persons Killed - 2014           0
# Fine - Persons Injured - 2014          1
#                                       ..
# Dust Storm - Persons Killed - 2016     0
# Dust Storm - Persons Injured - 2016    0
# Others - Total Accidents - 2016        0
# Others - Persons Killed - 2016         0
# Others - Persons Injured - 2016        0
# Length: 65, dtype: int64

# %%
print("Total number of missing values: {}".format(data.isna().sum().sum()))
print("Number of columns with missing values: {}".format(len(data.isnull().sum().tolist())-data.isnull().sum().tolist().count(0)))
print("Number of columns without missing values: {}".format(data.isnull().sum().tolist().count(0)))
# Out:
# Total number of missing values: 35
# Number of columns with missing values: 35
# Number of columns without missing values: 30

# %%
# Summary of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 65 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   S. No.                                                          37 non-null     object
#  1   State/ UT                                                       37 non-null     object
#  2   Fine - Total Acc. - 2014                                        36 non-null     float64
#  3   Fine - Persons Killed - 2014                                    37 non-null     int64
#  4   Fine - Persons Injured - 2014                                   36 non-null     float64
#  5   Mist/fog - Total Acc. - 2014                                    36 non-null     float64
#  6   Mist/fog - Persons Killed - 2014                                37 non-null     int64
#  7   Mist/fog - Persons Injured - 2014                               36 non-null     float64
#  8   Cloudy - Total Acc. - 2014                                      36 non-null     float64
#  9   Cloudy - Persons Killed - 2014                                  36 non-null     float64
#  10  Cloudy - Persons Injured - 2014                                 36 non-null     float64
#  11  Light rain - Total Acc. - 2014                                  36 non-null     float64
#  12  Light rain - Persons Killed - 2014                              36 non-null     float64
#  13  Light rain - Persons Injured - 2014                             36 non-null     float64
#  14  Heavy rain - Total Acc. - 2014                                  36 non-null     float64
#  15  Heavy rain - Persons Killed - 2014                              37 non-null     int64
#  16  Heavy rain - Persons Injured - 2014                             36 non-null     float64
#  17  Flooding of slipways/rivulers - Total Acc. - 2014               36 non-null     float64
#  18  Flooding of slipways/rivulers - Persons Killed - 2014           36 non-null     float64
#  19  Flooding of slipways/rivulers - Persons Injured - 2014          36 non-null     float64
#  20  Hail/sleet - Total Acc. - 2014                                  36 non-null     float64
#  21  Hail/sleet - Persons Killed - 2014                              36 non-null     float64
#  22  Hail/sleet - Persons Injured - 2014                             36 non-null     float64
#  23  snow - Total Acc. - 2014                                        36 non-null     float64
#  24  snow - Persons Killed - 2014                                    36 non-null     float64
#  25  snow - Persons Injured - 2014                                   36 non-null     float64
#  26  Strong wind - Total Acc. - 2014                                 36 non-null     float64
#  27  Strong wind - Persons Killed - 2014                             37 non-null     int64
#  28  Strong wind - Persons Injured - 2014                            36 non-null     float64
#  29  Dust storm - Total Acc. - 2014                                  36 non-null     float64
#  30  Dust storm - Persons Killed - 2014                              36 non-null     float64
#  31  Dust storm - Persons Injured - 2014                             36 non-null     float64
#  32  Very hot - Total Acc. - 2014                                    36 non-null     float64
#  33  Very hot - Persons Killed - 2014                                36 non-null     float64
#  34  Very hot - Persons Injured - 2014                               36 non-null     float64
#  35  Very cold - Total Acc. - 2014                                   36 non-null     float64
#  36  Very cold - Persons Killed - 2014                               36 non-null     float64
#  37  Very cold - Persons Injured - 2014                              36 non-null     float64
#  38  Other extraordinary weather condition - Total Acc. - 2014       36 non-null     float64
#  39  Other extraordinary weather condition - Persons Killed - 2014   36 non-null     float64
#  40  Other extraordinary weather condition - Persons Injured - 2014  36 non-null     float64
#  41  Fine/Clear - Total Accidents - 2016                             37 non-null     int64
#  42  Fine/Clear - Persons Killed - 2016                              37 non-null     int64
#  43  Fine/Clear - Persons Injured - 2016                             37 non-null     int64
#  44  Mist/ Foggy - Total Accidents - 2016                            37 non-null     int64
#  45  Mist/ Foggy - Persons Killed - 2016                             37 non-null     int64
#  46  Mist/ Foggy - Persons Injured - 2016                            37 non-null     int64
#  47  Cloudy - Total Accidents - 2016                                 37 non-null     int64
#  48  Cloudy - Persons Killed - 2016                                  37 non-null     int64
#  49  Cloudy - Persons Injured - 2016                                 37 non-null     int64
#  50  Rainy - Total Accidents - 2016                                  37 non-null     int64
#  51  Rainy - Persons Killed - 2016                                   37 non-null     int64
#  52  Rainy - Persons Injured - 2016                                  37 non-null     int64
#  53  Snowfall - Total Accidents - 2016                               37 non-null     int64
#  54  Snowfall - Persons Killed - 2016                                37 non-null     int64
#  55  Snowfall - Persons Injured - 2016                               37 non-null     int64
#  56  Hail/Sleet - Total Accidents - 2016                             37 non-null     int64
#  57  Hail/Sleet - Persons Killed - 2016                              37 non-null     int64
#  58  Hail/Sleet - Persons Injured - 2016                             37 non-null     int64
#  59  Dust Storm - Total Accidents - 2016                             37 non-null     int64
#  60  Dust Storm - Persons Killed - 2016                              37 non-null     int64
#  61  Dust Storm - Persons Injured - 2016                             37 non-null     int64
#  62  Others - Total Accidents - 2016                                 37 non-null     int64
#  63  Others - Persons Killed - 2016                                  37 non-null     int64
#  64  Others - Persons Injured - 2016                                 37 non-null     int64
# dtypes: float64(35), int64(28), object(2)
# memory usage: 18.9+ KB

# %%
# Count of duplicates
print("Number of duplicate observations: {}".format(data.duplicated().sum()))
# Out:
# Number of duplicate observations: 0

# %%
# Statistical description of numerical features
data.describe()
# Out:
#        Fine - Total Acc. - 2014  Fine - Persons Killed - 2014  \
# count                 36.000000                     37.000000
# mean               17228.944444                   4525.783784
# std                52035.194929                  13727.102371
# min                    0.000000                      0.000000
# 25%                  245.250000                     72.000000
# 50%                 3565.500000                   1218.000000
# 75%                12260.750000                   3622.000000
# max               310121.000000                  83727.000000
#
#        Fine - Persons Injured - 2014  Mist/fog - Total Acc. - 2014  \
# count                      36.000000                     36.000000
# mean                    17369.833333                    949.444444
# std                     52418.739891                   2833.826393
# min                         0.000000                      0.000000
# 25%                       303.500000                     14.000000
# 50%                      2702.000000                    288.500000
# 75%                     11885.500000                    724.000000
# max                    312657.000000                  17090.000000
#
#        Mist/fog - Persons Killed - 2014  Mist/fog - Persons Injured - 2014  \
# count                         37.000000                          36.000000
# mean                         318.162162                         808.888889
# std                          969.205187                        2408.170803
# min                            0.000000                           0.000000
# 25%                            7.000000                          19.750000
# 50%                           48.000000                         260.000000
# 75%                          245.000000                         724.250000
# max                         5886.000000                       14560.000000
#
#        Cloudy - Total Acc. - 2014  Cloudy - Persons Killed - 2014  \
# count                   36.000000                       36.000000
# mean                   876.111111                      260.388889
# std                   2619.361076                      776.087781
# min                      0.000000                        0.000000
# 25%                     23.000000                        5.750000
# 50%                    243.000000                       93.000000
# 75%                    707.000000                      213.750000
# max                  15770.000000                     4687.000000
#
#        Cloudy - Persons Injured - 2014  Light rain - Total Acc. - 2014  ...  \
# count                        36.000000                       36.000000  ...
# mean                       1016.444444                     1488.833333  ...
# std                        3058.268908                     4448.678664  ...
# min                           0.000000                        0.000000  ...
# 25%                          22.250000                       29.750000  ...
# 50%                         242.000000                      305.000000  ...
# 75%                         849.000000                     1230.250000  ...
# max                       18296.000000                    26799.000000  ...
#
#        Snowfall - Persons Injured - 2016  Hail/Sleet - Total Accidents - 2016  \
# count                          37.000000                            37.000000
# mean                            3.135135                            75.081081
# std                            10.588679                           236.932759
# min                             0.000000                             0.000000
# 25%                             0.000000                             0.000000
# 50%                             0.000000                             0.000000
# 75%                             0.000000                            47.000000
# max                            58.000000                          1389.000000
#
#        Hail/Sleet - Persons Killed - 2016  \
# count                           37.000000
# mean                            39.567568
# std                            126.153905
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                             23.000000
# max                            732.000000
#
#        Hail/Sleet - Persons Injured - 2016  \
# count                            37.000000
# mean                            110.324324
# std                             351.916109
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                              42.000000
# max                            2041.000000
#
#        Dust Storm - Total Accidents - 2016  \
# count                            37.000000
# mean                            283.837838
# std                             887.277437
# min                               0.000000
# 25%                               0.000000
# 50%                               4.000000
# 75%                             243.000000
# max                            5251.000000
#
#        Dust Storm - Persons Killed - 2016  \
# count                           37.000000
# mean                           116.054054
# std                            369.037558
# min                              0.000000
# 25%                              0.000000
# 50%                              2.000000
# 75%                             95.000000
# max                           2147.000000
#
#        Dust Storm - Persons Injured - 2016  Others - Total Accidents - 2016  \
# count                            37.000000                        37.000000
# mean                            318.648649                      2783.243243
# std                             982.370580                      8598.834506
# min                               0.000000                         0.000000
# 25%                               0.000000                         0.000000
# 50%                               5.000000                       132.000000
# 75%                             318.000000                      2187.000000
# max                            5895.000000                     51490.000000
#
#        Others - Persons Killed - 2016  Others - Persons Injured - 2016
# count                       37.000000                        37.000000
# mean                      1040.810811                      2774.162162
# std                       3243.597693                      8579.269512
# min                          0.000000                         0.000000
# 25%                          0.000000                         0.000000
# 50%                         53.000000                        91.000000
# 75%                        881.000000                      2036.000000
# max                      19255.000000                     51322.000000
#
# [8 rows x 63 columns]

# %%
# Total count, unique count, mode value and mode frequency of all features
data.describe(include = "all").head(4).T
# Out:
#                                     count unique             top freq
# S. No.                                 37     37               1    1
# State/ UT                              37     37  Andhra Pradesh    1
# Fine - Total Acc. - 2014             36.0    NaN             NaN  NaN
# Fine - Persons Killed - 2014         37.0    NaN             NaN  NaN
# Fine - Persons Injured - 2014        36.0    NaN             NaN  NaN
# ...                                   ...    ...             ...  ...
# Dust Storm - Persons Killed - 2016   37.0    NaN             NaN  NaN
# Dust Storm - Persons Injured - 2016  37.0    NaN             NaN  NaN
# Others - Total Accidents - 2016      37.0    NaN             NaN  NaN
# Others - Persons Killed - 2016       37.0    NaN             NaN  NaN
# Others - Persons Injured - 2016      37.0    NaN             NaN  NaN
#
# [65 rows x 4 columns]

# %%
# Unique values of Accident_severity
data['Dust Storm - Persons Killed - 2016'].unique()
# Out:
# array([  34,    0,   14,  318,   28,  115,  150,  108,  151,   68,  119,
#          95,   39,    4,    2,    5,  759,  109,   27, 2147], dtype=int64)

# %%
# Value counts of Accident_severity
data['Dust Storm - Persons Killed - 2016'].value_counts()
# Out:
# 0       17
# 2        2
# 34       1
# 27       1
# 109      1
# 759      1
# 5        1
# 4        1
# 39       1
# 95       1
# 119      1
# 68       1
# 151      1
# 108      1
# 150      1
# 115      1
# 28       1
# 318      1
# 14       1
# 2147     1
# Name: Dust Storm - Persons Killed - 2016, dtype: int64

# %%
def add_annotations(ax):
    for p in ax.patches:
        frequency = p.get_height()
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        ax.annotate(f'{frequency}', (x, y), size = 12, ha = 'center', va = 'bottom')

# Visualization
def count_donut(data, col):
    plt.figure(figsize = (14, 7))

    # Countplot
    ax1 = plt.subplot(1, 2, 1)
    count = sns.countplot(x = data[col])
    ax1.set_xlabel('')
    ax1.set_ylabel('')
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    sns.despine(top = True, right = True)
    add_annotations(ax1)

    # Donutplot
    ax2 = plt.subplot(1, 2, 2)
    plt.pie(data[col].value_counts(),
            labels = data[col].unique().tolist(),
            autopct = '%1.2f%%',
            pctdistance = 0.8,
            shadow = False,
            radius = 1.3,
            textprops = {'fontsize' : 14}
            )
    circle = plt.Circle((0, 0), 0.4, fc = 'white')
    fig = plt.gcf()
    fig.gca().add_artist(circle)
    ax2.set_xlabel('')

    plt.suptitle("Frequency Comparison of {}".format(col), fontsize = 16)
    plt.subplots_adjust(wspace = 0.4)
    plt.show()

# %%
count_donut(data, 'Dust Storm - Persons Killed - 2016')

# %%
# File system manangement
import time, psutil, os

# Mathematical functions
import math

# Data manipulation
import numpy as np
import pandas as pd

# Plotting and visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Missing data imputation
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, KNNImputer, IterativeImputer

# Categorical data encoding
from sklearn.preprocessing import LabelEncoder

# Train-test split and k-fold cross validation
from sklearn.model_selection import train_test_split, KFold,  GridSearchCV

# Feature selection
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif

# Resampling
import imblearn
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from imblearn.over_sampling import RandomOverSampler, SMOTE

# Classification algorithms
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
# Model evaluation
from sklearn import metrics
from sklearn.metrics import f1_score

# # Explainable AI
# !pip install --quiet shap==0.39.0
# import shap

# # Warning suppression
# import warnings
# warnings.filterwarnings('ignore')

# %%
# Recording the starting time, which will be complemented with a time check at the end, to compute the total runtime of the process
start = time.time()
